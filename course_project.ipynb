# %% [markdown]
# # DHHB Course Project

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Fontconfig error: Cannot load default config file: No such file: (null)

# %%
#Let's first download all files we want to use and read them into pandas dataframes

activity = pd.read_csv("dailyActivity_merged.csv")
weight = pd.read_csv("weightLogInfo_merged.csv")
sleep = pd.read_csv("sleepDay_merged.csv")

#Let's then take a look at every dataframe individually
activity
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    4/12/2016       13162       8.500000         8.500000
# 1    1503960366    4/13/2016       10735       6.970000         6.970000
# 2    1503960366    4/14/2016       10460       6.740000         6.740000
# 3    1503960366    4/15/2016        9762       6.280000         6.280000
# 4    1503960366    4/16/2016       12669       8.160000         8.160000
# ..          ...          ...         ...            ...              ...
# 935  8877689391     5/8/2016       10686       8.110000         8.110000
# 936  8877689391     5/9/2016       20226      18.250000        18.250000
# 937  8877689391    5/10/2016       10733       8.150000         8.150000
# 938  8877689391    5/11/2016       21420      19.559999        19.559999
# 939  8877689391    5/12/2016        8064       6.120000         6.120000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# ...

# %%
sleep
# Out:
#              Id               SleepDay  TotalSleepRecords  TotalMinutesAsleep  \
# 0    1503960366  4/12/2016 12:00:00 AM                  1                 327
# 1    1503960366  4/13/2016 12:00:00 AM                  2                 384
# 2    1503960366  4/15/2016 12:00:00 AM                  1                 412
# 3    1503960366  4/16/2016 12:00:00 AM                  2                 340
# 4    1503960366  4/17/2016 12:00:00 AM                  1                 700
# ..          ...                    ...                ...                 ...
# 408  8792009665  4/30/2016 12:00:00 AM                  1                 343
# 409  8792009665   5/1/2016 12:00:00 AM                  1                 503
# 410  8792009665   5/2/2016 12:00:00 AM                  1                 415
# 411  8792009665   5/3/2016 12:00:00 AM                  1                 516
# 412  8792009665   5/4/2016 12:00:00 AM                  1                 439
#
#      TotalTimeInBed
# ...

# %%
weight
# Out:
#             Id                   Date    WeightKg  WeightPounds   Fat  \
# 0   1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1   1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2   1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3   2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4   2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
# ..         ...                    ...         ...           ...   ...
# 62  8877689391    5/6/2016 6:43:35 AM   85.000000    187.392923   NaN
# 63  8877689391    5/8/2016 7:35:53 AM   85.400002    188.274775   NaN
# 64  8877689391    5/9/2016 6:39:44 AM   85.500000    188.495234   NaN
# 65  8877689391   5/11/2016 6:51:47 AM   85.400002    188.274775   NaN
# 66  8877689391   5/12/2016 6:42:53 AM   84.000000    185.188300   NaN
#
#           BMI  IsManualReport          LogId
# 0   22.650000            True  1462233599000
# ...

# %%
#Let's check for any null values in the dataframes

print(activity.isnull().sum(axis = 0))
print(weight.isnull().sum(axis = 0))
print(sleep.isnull().sum(axis = 0))

#Here we notice that there are hardly any null values except for the Fat column in weight dataframe
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64
# Id                 0
# Date               0
# WeightKg           0
# WeightPounds       0
# Fat               65
# BMI                0
# IsManualReport     0
# LogId              0
# dtype: int64
# Id                    0
# SleepDay              0
# TotalSleepRecords     0
# TotalMinutesAsleep    0
# TotalTimeInBed        0
# dtype: int64

# %%
#Let's then check how many unique ids these datasets have

print(activity.Id.nunique())
print(sleep.Id.nunique())
print(weight.Id.nunique())

#It seems that there are very little weight logs in the data set
# Out:
# 33
# 24
# 8

# %%
sleep.Id.value_counts()
# Out:
# 8378563200    32
# 6962181067    31
# 5553957443    31
# 4702921684    28
# 2026352035    28
# 3977333714    28
# 4445114986    28
# 5577150313    26
# 4319703577    26
# 1503960366    25
# 7086361926    24
# 4388161847    24
# 6117666160    18
# 8792009665    15
# 2347167796    15
# 4020332650     8
# 1927972279     5
# 4558609924     5
# 1644430081     4
# 6775888955     3
# 8053475328     3
# 1844505072     3
# 7007744171     2
# 2320127002     1
# Name: Id, dtype: int64

# %%
weight.Id.value_counts()
#Here we notice also that 95% of the weight logs come from only two participants -> very little and biased data
# Out:
# 6962181067    30
# 8877689391    24
# 4558609924     5
# 1503960366     2
# 2873212765     2
# 4319703577     2
# 1927972279     1
# 5577150313     1
# Name: Id, dtype: int64

# %%
print((activity.LoggedActivitiesDistance==0).sum())
activity.describe()

#Here we see LoggedActivitiesDistance values are mostly zero so it's not really giving any useful information for us
# Out:
# 908
#                  Id    TotalSteps  TotalDistance  TrackerDistance  \
# count  9.400000e+02    940.000000     940.000000       940.000000
# mean   4.855407e+09   7637.910638       5.489702         5.475351
# std    2.424805e+09   5087.150742       3.924606         3.907276
# min    1.503960e+09      0.000000       0.000000         0.000000
# 25%    2.320127e+09   3789.750000       2.620000         2.620000
# 50%    4.445115e+09   7405.500000       5.245000         5.245000
# 75%    6.962181e+09  10727.000000       7.712500         7.710000
# max    8.877689e+09  36019.000000      28.030001        28.030001
#
#        LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# count                940.000000          940.000000                940.000000
# mean                   0.108171            1.502681                  0.567543
# std                    0.619897            2.658941                  0.883580
# ...

# %%
#Let's make a plot to find if any of the activity features correlate with each other
plt.figure(figsize = [10,8])
sns.heatmap(data = activity.corr("pearson"), annot = True, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
#Let's drop some unnecessary features
activity = activity.drop(["TrackerDistance","LoggedActivitiesDistance","VeryActiveDistance",
                          "ModeratelyActiveDistance","LightActiveDistance","SedentaryActiveDistance"], axis = 1)
activity['ActiveMinutes'] = activity.VeryActiveMinutes+activity.FairlyActiveMinutes
activity
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  VeryActiveMinutes  \
# 0    1503960366    4/12/2016       13162       8.500000                 25
# 1    1503960366    4/13/2016       10735       6.970000                 21
# 2    1503960366    4/14/2016       10460       6.740000                 30
# 3    1503960366    4/15/2016        9762       6.280000                 29
# 4    1503960366    4/16/2016       12669       8.160000                 36
# ..          ...          ...         ...            ...                ...
# 935  8877689391     5/8/2016       10686       8.110000                 17
# 936  8877689391     5/9/2016       20226      18.250000                 73
# 937  8877689391    5/10/2016       10733       8.150000                 18
# 938  8877689391    5/11/2016       21420      19.559999                 88
# 939  8877689391    5/12/2016        8064       6.120000                 23
#
# ...

# %%
#Let's change date data to datetime format to make data processing easier

activity["ActivityDate"] = pd.to_datetime(activity['ActivityDate']).dt.strftime('%m/%d/%Y')
sleep["SleepDay"] = pd.to_datetime(sleep['SleepDay']).dt.strftime('%m/%d/%Y')
weight["Date"] = pd.to_datetime(weight['Date']).dt.strftime('%m/%d/%Y')
activity.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 940 entries, 0 to 939
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    940 non-null    int64
#  1   ActivityDate          940 non-null    object
#  2   TotalSteps            940 non-null    int64
#  3   TotalDistance         940 non-null    float64
#  4   VeryActiveMinutes     940 non-null    int64
#  5   FairlyActiveMinutes   940 non-null    int64
#  6   LightlyActiveMinutes  940 non-null    int64
#  7   SedentaryMinutes      940 non-null    int64
#  8   Calories              940 non-null    int64
#  9   ActiveMinutes         940 non-null    int64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 73.6+ KB

# %%
#Let's drop some unnecessary features

weight = weight.drop(["WeightPounds","Fat","IsManualReport","LogId"], axis = 1)
weight
# Out:
#             Id        Date    WeightKg        BMI
# 0   1503960366  05/02/2016   52.599998  22.650000
# 1   1503960366  05/03/2016   52.599998  22.650000
# 2   1927972279  04/13/2016  133.500000  47.540001
# 3   2873212765  04/21/2016   56.700001  21.450001
# 4   2873212765  05/12/2016   57.299999  21.690001
# ..         ...         ...         ...        ...
# 62  8877689391  05/06/2016   85.000000  25.440001
# 63  8877689391  05/08/2016   85.400002  25.559999
# 64  8877689391  05/09/2016   85.500000  25.610001
# 65  8877689391  05/11/2016   85.400002  25.559999
# 66  8877689391  05/12/2016   84.000000  25.139999
#
# [67 rows x 4 columns]

# %%
#Let's name all change date info containing columns' names into "Date" to make dataframe joining easier
activity = activity.rename(columns = {"ActivityDate":"Date"})
sleep = sleep.rename(columns = {"SleepDay":"Date"})

# %%
#First, let's take a closer look at the average stepcount of participants, because it's FitBit's most accurate measurement

df = activity[["Id","TotalSteps"]]

#Let's only take into an account the non-zero values
df = df[df.TotalSteps > 0]
df = df.groupby(['Id']).mean()
print(df.mean().TotalSteps)

#Create a graph
plt.figure(figsize=(16,8))
plt.suptitle("Average stepcount per user id",fontsize=20)
g1 = sns.barplot(data=df,x=df.index,y="TotalSteps",alpha=0.5)
g1.set_xticklabels(df.index, rotation=60, fontsize = 8)
g1.axhline(df.mean().TotalSteps,color="black")
g1.axhline(7000,color="green")
# Out:
# 7921.905628984993

# %%
#Let's then investigate average sleeping times of the participants

df2 = sleep[["Id","TotalMinutesAsleep"]]

plt.figure(figsize=(16,8))
plt.suptitle("Average sleep time",fontsize=20)
sns.histplot(x = df2.groupby("Id").TotalMinutesAsleep.mean()/60, bins = 12, color="darkblue",kde=True)
print(df2.mean().TotalMinutesAsleep/60)
# Out:
# 6.991121872477804

# %%
activity['ActiveHours']=activity['ActiveMinutes']/60
activity
# Out:
#              Id        Date  TotalSteps  TotalDistance  VeryActiveMinutes  \
# 0    1503960366  04/12/2016       13162       8.500000                 25
# 1    1503960366  04/13/2016       10735       6.970000                 21
# 2    1503960366  04/14/2016       10460       6.740000                 30
# 3    1503960366  04/15/2016        9762       6.280000                 29
# 4    1503960366  04/16/2016       12669       8.160000                 36
# ..          ...         ...         ...            ...                ...
# 935  8877689391  05/08/2016       10686       8.110000                 17
# 936  8877689391  05/09/2016       20226      18.250000                 73
# 937  8877689391  05/10/2016       10733       8.150000                 18
# 938  8877689391  05/11/2016       21420      19.559999                 88
# 939  8877689391  05/12/2016        8064       6.120000                 23
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# ...

# %%
#Let's join sleeop and activity dataframes to investigate the relationship between sleep and activity

data_joined = activity.set_index(["Id","Date"]).join(sleep.set_index(["Id","Date"]),how="right")
data_joined = data_joined.reset_index()
data_joined["TotalHoursAsleep"] = data_joined.TotalMinutesAsleep/60
data_joined
# Out:
#              Id        Date  TotalSteps  TotalDistance  VeryActiveMinutes  \
# 0    1503960366  04/12/2016       13162           8.50                 25
# 1    1503960366  04/13/2016       10735           6.97                 21
# 2    1503960366  04/15/2016        9762           6.28                 29
# 3    1503960366  04/16/2016       12669           8.16                 36
# 4    1503960366  04/17/2016        9705           6.48                 38
# ..          ...         ...         ...            ...                ...
# 408  8792009665  04/30/2016        7174           4.59                 10
# 409  8792009665  05/01/2016        1619           1.04                  0
# 410  8792009665  05/02/2016        1831           1.17                  0
# 411  8792009665  05/03/2016        2421           1.55                  0
# 412  8792009665  05/04/2016        2283           1.46                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# ...

# %%
#Create a plot

data_joined['ActivityType'] = np.where(data_joined.ActiveHours > 1, "Active", "Inactive")
plt.figure(figsize=(16,8))
plt.suptitle("Sleep time per activity type",fontsize=20)
sns.histplot(data=data_joined, x="TotalHoursAsleep", hue="ActivityType", bins=12,kde=True,multiple="stack",palette="Blues")
# Out:
# <AxesSubplot:xlabel='TotalHoursAsleep', ylabel='Count'>

# %%
plt.figure(figsize=(16,8))
plt.suptitle("Sedentary minutes and total hours asleep",fontsize=20)
sns.scatterplot(x = data_joined.TotalHoursAsleep, y = data_joined.SedentaryMinutes, color="darkblue")
#Here we notice that TotalHoursAsleep and SedentaryMinutes correlate negatively
# Out:
# <AxesSubplot:xlabel='TotalHoursAsleep', ylabel='SedentaryMinutes'>

# %%
#Finally, let's see how BMI affects activity
data_joined2 = activity.set_index(["Id","Date"]).join(weight.set_index(["Id","Date"]),how="right")
data_joined2 = data_joined2.reset_index()
data_joined2['WeightLabel'] = data_joined2['BMI'].apply(lambda x: 'Overweight' if x >= 25 else ('Normal' if (x < 25 and x >= 18.5) else 'Underweight'))
data_joined2
# Out:
#             Id        Date  TotalSteps  TotalDistance  VeryActiveMinutes  \
# 0   1503960366  05/02/2016       14727       9.710000                 41
# 1   1503960366  05/03/2016       15103       9.660000                 50
# 2   1927972279  04/13/2016         356       0.250000                  0
# 3   2873212765  04/21/2016        8859       5.980000                  2
# 4   2873212765  05/12/2016        7566       5.110000                  0
# ..         ...         ...         ...            ...                ...
# 62  8877689391  05/06/2016       21727      19.340000                 96
# 63  8877689391  05/08/2016       10686       8.110000                 17
# 64  8877689391  05/09/2016       20226      18.250000                 73
# 65  8877689391  05/11/2016       21420      19.559999                 88
# 66  8877689391  05/12/2016        8064       6.120000                 23
#
#     FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# ...

# %%
#Let's only take into an account the non-zero values
data_joined2 = data_joined2[data_joined2.TotalSteps > 0]
data_joined2 = data_joined2.groupby(['Id']).mean()
data_joined2['WeightLabel'] = data_joined2['BMI'].apply(lambda x: 'Overweight' if x >= 25 else ('Normal' if (x < 25 and x >= 18.5) else 'Underweight'))

# %%
data_joined2 = data_joined2.groupby(['WeightLabel']).mean()
data_joined2
# Out:
#                TotalSteps  TotalDistance  VeryActiveMinutes  \
# WeightLabel
# Normal       10967.011111       7.268444          22.955556
# Overweight    8559.841667       6.523633          55.928333
#
#              FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  \
# WeightLabel
# Normal                 14.466667            276.844444        785.744444
# Overweight             12.866667            180.320000        982.723333
#
#                 Calories  ActiveMinutes  ActiveHours   WeightKg        BMI
# WeightLabel
# Normal       1892.844444      37.422222     0.623704  57.051111  22.749333
# Overweight   2818.971667      68.795000     1.146583  90.267167  31.131217

# %%
plt.figure(figsize=(16,8))
plt.suptitle("Average stepcount per weight label",fontsize=20)
sns.barplot(data=data_joined2, x=data_joined2.index, y="TotalSteps", palette="Blues")
# Out:
# <AxesSubplot:xlabel='WeightLabel', ylabel='TotalSteps'>
